# %%
import pandas as pd

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv("C:\\Users\\jyoti\\OneDrive\\Desktop\\New folder\\covid_toy")

# %%
df=pd.read_csv("C:\\Users\\jyoti\\OneDrive\\Desktop\\New folder\\covid_toy.csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.sample(5)
# Out:
#     age  gender  fever   cough     city has_covid
# 44   20    Male  102.0  Strong    Delhi        No
# 49   44    Male  104.0    Mild   Mumbai        No
# 75    5    Male  102.0    Mild  Kolkata       Yes
# 1    27    Male  100.0    Mild    Delhi       Yes
# 96   51  Female  101.0  Strong  Kolkata       Yes

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df['city']
# Out:
# 0       Kolkata
# 1         Delhi
# 2         Delhi
# 3       Kolkata
# 4        Mumbai
#         ...
# 95    Bangalore
# 96      Kolkata
# 97    Bangalore
# 98       Mumbai
# 99      Kolkata
# Name: city, Length: 100, dtype: object

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['city'][2]='Jaipur'
# Out:
# C:\Users\jyoti\AppData\Local\Temp\ipykernel_29712\1375774670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'][2]='Jaipur'

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild     Jaipur        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.loc[12:89,['age', 'gender', 'fever']]
# Out:
#     age  gender  fever
# 12   25  Female   99.0
# 13   64    Male  102.0
# 14   51    Male  104.0
# 15   70    Male  103.0
# 16   69  Female  103.0
# ..  ...     ...    ...
# 85   16  Female  103.0
# 86   25    Male  104.0
# 87   47    Male  101.0
# 88    5  Female  100.0
# 89   46    Male  103.0
#
# [78 rows x 3 columns]

# %%
df.iloc[0:5,[1,2,5]]
# Out:
#    gender  fever has_covid
# 0    Male  103.0        No
# 1    Male  100.0       Yes
# 2    Male  101.0        No
# 3  Female   98.0        No
# 4  Female  101.0        No
